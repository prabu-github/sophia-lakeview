# %%
# %%writefile trait.py
from __future__ import annotations
import sys
from pathlib import Path
from pprint import pprint

hytraits_path = (Path(__file__).parent.parent/'hytraits').resolve()
if str(hytraits_path) not in sys.path:
    sys.path.append(str(hytraits_path))
import hytraits as H
from utils import (get_trait_args,
                   get_paths,
                   get_train_config_json,
                   get_deploy_config_jsons,
                   get_eda_config_json)


if __name__ == '__main__':
    args = get_trait_args()
    verbose = args['verbose']

    PATHS = get_paths()

    train_json = get_train_config_json(train_config_idx=args['train_config_idx'],
                                       train_config_stem=args['train_config_stem'])
    if train_json is not None:
        message = f'====== Training: {train_json.name}'
        if args['train_config_idx'] is not None:
            message += f' (idx = {args["train_config_idx"]}) ...'
        print(message)
        
        # TRAINER = H.TraitTrainer()
        # TRAINER(config_json=train_json)

    deploy_jsons = get_deploy_config_jsons(train_config_idx=args['train_config_idx'],
                                           train_config_stem=args['train_config_stem'])
    if deploy_jsons is not None:
        message = f'====== Deploying: {train_json.name}'
        if args['train_config_idx'] is not None:
            message += f' (idx = {args["train_config_idx"]}) ...'
        message += f' ({len(deploy_jsons)})'
        print(message)

        for deploy_json in deploy_jsons:
            print(f'-----{deploy_json.stem}')

        # for deploy_json in deploy_jsons:
        #     DEPLOYER = H.TraitDeployerCSV()
        #     DEPLOYER(config_json=deploy_json)

    eda_json = get_eda_config_json(eda_config_idx=args['eda_config_idx'],
                                   eda_config_stem=args['eda_config_stem'])
    if eda_json is not None:
        message = f'====== EDA: {eda_json.name}'
        if args['eda_config_idx'] is not None:
            message += f' (idx = {args["eda_config_idx"]}) ...'
        print(message)
        
        # EDA = H.EDA()
        # EDA(config_json=eda_json)
# Out:
# Overwriting trait.py

# %%
! python trait.py --train_config_idx 1;
! python trait.py --train_config_stem TRAIN__plsr__400-800-asis-log__cfpc;
! python trait.py --train_config_idx 200;
! python trait.py --train_config_stem TRAIN__plsr__400-800-asis-log__cfp;
# Out:
# ====== Training: TRAIN__plsr__400-800-asis-log__cfpc.json (idx = 1) ...
# ====== Deploying: TRAIN__plsr__400-800-asis-log__cfpc.json (idx = 1) ... (1)
# -----DEPLOY__plsr__400-800-asis-log__cfpc__TEST__cfpc
# ====== Training: TRAIN__plsr__400-800-asis-log__cfpc.json
# ====== Deploying: TRAIN__plsr__400-800-asis-log__cfpc.json (1)
# -----DEPLOY__plsr__400-800-asis-log__cfpc__TEST__cfpc
# Traceback (most recent call last):
#   File "/home/pravindran/projworks/sophia-lakeview/trait.py", line 23, in <module>
#     train_json = get_train_config_json(train_config_idx=args['train_config_idx'],
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/pravindran/projworks/sophia-lakeview/utils.py", line 515, in get_train_config_json
#     raise Exception(f'{train_config_idx} is invalid.')
# Exception: 200 is invalid.
# Traceback (most recent call last):
#   File "/home/pravindran/projworks/sophia-lakeview/trait.py", line 23, in <module>
#     train_json = get_train_config_json(train_config_idx=args['train_config_idx'],
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/pravindran/projworks/sophia-lakeview/utils.py", line 523, in get_train_config_json
#     raise Exception(f'{train_config_stem} is not found.')
# Exception: TRAIN__plsr__400-800-asis-log__cfp is not found.

# %%
! python trait.py --eda_config_idx 1;
! python trait.py --eda_config_stem EDA__log__cfpc;
! python trait.py --eda_config_idx 20;
! python trait.py --eda_config_stem EDA__lg__cfpc;
# Out:
# ====== EDA: EDA__log__cfpc.json (idx = 1) ...
# ====== EDA: EDA__log__cfpc.json
# Traceback (most recent call last):
#   File "/home/pravindran/projworks/sophia-lakeview/trait.py", line 50, in <module>
#     eda_json = get_eda_config_json(eda_config_idx=args['eda_config_idx'],
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/pravindran/projworks/sophia-lakeview/utils.py", line 583, in get_eda_config_json
#     raise Exception(f'{eda_config_idx} is invalid.')
# Exception: 20 is invalid.
# Traceback (most recent call last):
#   File "/home/pravindran/projworks/sophia-lakeview/trait.py", line 50, in <module>
#     eda_json = get_eda_config_json(eda_config_idx=args['eda_config_idx'],
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/pravindran/projworks/sophia-lakeview/utils.py", line 592, in get_eda_config_json
#     raise Exception(f'{eda_config_stem} is not found.')
# Exception: EDA__lg__cfpc is not found.
