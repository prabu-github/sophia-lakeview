# %%
from pathlib import Path
import numpy as np
import pandas as pd
import zipfile

# %%
test_dir = Path('io/test')

with zipfile.ZipFile(test_dir/'fromnode.zip', 'r') as myzip:
    myzip.extractall(test_dir)
# Out:
# len(model_zipfiles) = 168, len(ideploy_zipfiles) = 168, len(edeploy_zipfiles) = 168

# %%
for z in (test_dir/'fromnode/model').glob('*.zip'):
    print(z)
# Out:
# io/test/fromnode/model/plsr__median-min__450-800-asis-uv__so4-avg.zip
# io/test/fromnode/model/plsr__median-min__440-800-asis-uv__tp-avg.zip
# io/test/fromnode/model/plsr__median-min__400-800-move-uv__cfchl-avg.zip
# io/test/fromnode/model/plsr__median-min__440-800-move-uv__cfchl-avg.zip
# io/test/fromnode/model/plsr__median-min__440-800-move-uv__tp-avg.zip
# io/test/fromnode/model/plsr__median-min__440-800-move-uv__ic-avg.zip
# io/test/fromnode/model/plsr__median-min__450-800-move-uv__nh4-avg.zip
# io/test/fromnode/model/plsr__median-min__400-800-move-uv__si-avg.zip
# io/test/fromnode/model/plsr__median-min__450-800-asis-uv__npoc-avg.zip
# io/test/fromnode/model/plsr__median-min__450-800-move-uv__pcchl-avg.zip
# io/test/fromnode/model/plsr__median-min__400-800-asis-uv__si-avg.zip
# io/test/fromnode/model/plsr__median-min__410-800-asis-uv__cl-avg.zip
# io/test/fromnode/model/plsr__median-min__430-800-asis-uv__so4-avg.zip
# ...
