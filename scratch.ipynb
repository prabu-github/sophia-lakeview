# %%
from pathlib import Path
import numpy as np
import pandas as pd

# %%
csv_file = Path('io/original/LakeViewDF_v3.csv')
df = pd.read_csv(csv_file, low_memory=False)
print(df.shape)
# Out:
# (154, 437)

# %%
for c in df.columns[:30]:
    print(repr(c))
# Out:
# 'sampleID'
# 'date'
# 'event'
# 'site'
# 'temp_C'
# 'mmHg'
# 'DO_pct'
# 'DO_conc'
# 'SPcond'
# 'cond'
# 'IC'
# 'NPOC'
# 'Cl(-)'
# 'SO4(2-)'
# 'Silica'
# 'NO2/NO3 '
# 'SRP'
# 'NH4(+)'
# 'TN'
# 'TP'
# 'TSS'
# 'CF_chl'
# 'CF_PC'
# 'PC:chl'
# 'secchi_avg'
# '405.44'
# '408.64'
# '411.83'
# '415.02'
# '418.21'
